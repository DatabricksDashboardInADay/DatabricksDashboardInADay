-- %%
CREATE OR REPLACE TABLE sunny_bay_roastery.bronze.customer AS
SELECT * FROM read_files(
  '/Volumes/sunny_bay_roastery/bronze/raw/dim_customer/',
  format => 'csv',
  header => true,
  inferSchema => true
);



CREATE OR REPLACE TABLE sunny_bay_roastery.bronze.date AS
SELECT * FROM read_files(
  '/Volumes/sunny_bay_roastery/bronze/raw/dim_date/',
  format => 'csv',
  header => true,
  inferSchema => true
);


CREATE OR REPLACE TABLE sunny_bay_roastery.bronze.product AS
SELECT * FROM read_files(
  '/Volumes/sunny_bay_roastery/bronze/raw/dim_product/',
  format => 'csv',
  header => true,
  inferSchema => true
);

CREATE OR REPLACE TABLE sunny_bay_roastery.bronze.store AS
SELECT * FROM read_files(
  '/Volumes/sunny_bay_roastery/bronze/raw/dim_store/',
  format => 'csv',
  header => true,
  inferSchema => true
);

CREATE OR REPLACE TABLE sunny_bay_roastery.bronze.sales AS
SELECT * FROM read_files(
  '/Volumes/sunny_bay_roastery/bronze/raw/fact_coffee_sales/',
  format => 'parquet',
  header => true,
  inferSchema => true
);
